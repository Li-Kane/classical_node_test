# %%
import cv2
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Loading data

# %%
# Initialize an empty dictionary to store the image data
images = {}
folder_path = './images/'
file_names = os.listdir(folder_path)

# Loop through each file in the folder and load the image
for file_name in file_names:
    # Construct the full file path
    image_path = os.path.join(folder_path, file_name)
    
    # Load the image using OpenCV
    image = cv2.imread(image_path)
    if image is not None:
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        images[file_name] = image_rgb

# %%
# Set up the figure with 10 rows and 5 columns
fig, axes = plt.subplots(10, 5, figsize=(10, 20))

# Loop through each image and plot it in the grid
for idx, (file_name, image_data) in enumerate(images.items()):
    # Calculate the row and column index
    row = idx // 5
    col = idx % 5
    
    # Display the image in the corresponding subplot
    axes[row, col].imshow(image_data)
    axes[row, col].axis('off')  # Turn off the axis for each subplot

# Adjust layout for better spacing between images
plt.tight_layout()
plt.show()

# %% [markdown]
# # Testing classical_node

# %%
from src.decider import check_image, decide_to_shoot
import threading

# %%
opinions = []

def make_opinions(images):
    for image_key in images:
        opinion = check_image(images[image_key])
        print(opinion)
        opinions.append(opinion)

def print_decisions(opinions):
    for i in range(20):
        should_shoot = decide_to_shoot(opinions)
        #print("opinions length: ", len(opinions))
        #print(should_shoot)

t1 = threading.Thread(target=make_opinions, name='t1', args=(images,))
t2 = threading.Thread(target=print_decisions, name='t2', args=(opinions,))

t1.start()
t2.start()

t1.join()
t2.join()
# Out:
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
# ShootEnum.Shoot
