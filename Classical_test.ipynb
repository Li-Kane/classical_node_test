# %%
import cv2
import matplotlib.pyplot as plt

# %%
folder_path = './images/'
image_path = folder_path + 'image0.png'

# %%
image = cv2.imread(image_path)

plt.imshow(image)
plt.axis('off')
plt.show()
